# %%
from ortools.linear_solver import pywraplp

# %%
solver = pywraplp.Solver.CreateSolver('GLOP')

# %%
# ?solver
# Out:
# Type:           Solver
# String form:    <ortools.linear_solver.pywraplp.Solver; proxy of <Swig Object of type 'operations_research::MPSolver *' at 0x0000021BC0C28090> >
# File:           c:\users\thanh\appdata\roaming\python\python310\site-packages\ortools\linear_solver\pywraplp.py
# Docstring:
# This mathematical programming (MP) solver class is the main class
# though which users build and solve problems.
# Init docstring: Create a solver with the given name and underlying solver backend.

# %%
from ortools.sat.python import cp_model

# %%
model = cp_model.CpModel()

# %%
var_upper_bound = max(50, 45, 37)
x = model.new_int_var(0, var_upper_bound, "x")
y = model.new_int_var(0, var_upper_bound, "y")
z = model.new_int_var(0, var_upper_bound, "z")

# %%
# ?model.new_int_var
# Out:
# Signature:
# model.new_int_var(
#     lb: Union[numbers.Integral, int],
#     ub: Union[numbers.Integral, int],
#     name: str,
# ) -> ortools.sat.python.cp_model.IntVar
# Docstring:
# Create an integer variable with domain [lb, ub].
#
# The CP-SAT solver is limited to integer variables. If you have fractional
# values, scale them up so that they become integers; if you have strings,
# encode them as integers.
#
# Args:
#   lb: Lower bound for the variable.
#   ub: Upper bound for the variable.
#   name: The name of the variable.
#
# Returns:
#   a variable whose domain is [lb, ub].
# File:      c:\users\thanh\appdata\roaming\python\python310\site-packages\ortools\sat\python\cp_model.py
# Type:      method

# %%
x = model.new_int_var(0,14)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[11], line 1
# ----> 1 x = model.new_int_var(0,14)
#
# TypeError: CpModel.new_int_var() missing 1 required positional argument: 'name'

# %%
from ortools.sat.python import cp_model

# %%
model = cp_model.CpModel()

# %%
# ?model.add_linear_constraint
# Out:
# Signature:
# model.add_linear_constraint(
#     linear_expr: Union[ForwardRef('LinearExpr'), ForwardRef('IntVar'), numbers.Integral, int],
#     lb: Union[numbers.Integral, int],
#     ub: Union[numbers.Integral, int],
# ) -> ortools.sat.python.cp_model.Constraint
# Docstring: Adds the constraint: `lb <= linear_expr <= ub`.
# File:      c:\users\thanh\appdata\roaming\python\python310\site-packages\ortools\sat\python\cp_model.py
# Type:      method

# %%
# ?model.maximize
# Out:
# Signature:
# model.maximize(
#     obj: Union[ForwardRef('LinearExpr'), ForwardRef('IntVar'), numbers.Integral, int, numbers.Number, float],
# )
# Docstring: Sets the objective of the model to maximize(obj).
# File:      c:\users\thanh\appdata\roaming\python\python310\site-packages\ortools\sat\python\cp_model.py
# Type:      method

# %%
help(model)
# Out:
# Help on CpModel in module ortools.sat.python.cp_model object:
#
# class CpModel(builtins.object)
#  |  Methods for building a CP model.
#  |
#  |  Methods beginning with:
#  |
#  |  * ```New``` create integer, boolean, or interval variables.
#  |  * ```add``` create new constraints and add them to the model.
#  |
#  |  Methods defined here:
#  |
#  |  Add = add(self, ct: Union[ortools.sat.python.cp_model.BoundedLinearExpression, bool]) -> ortools.sat.python.cp_model.Constraint
#  |
#  |  AddAbsEquality = add_abs_equality(self, target: Union[ForwardRef('LinearExpr'), ForwardRef('IntVar'), numbers.Integral, int], expr: Union[ForwardRef('LinearExpr'), ForwardRef('IntVar'), numbers.Integral, int]) -> ortools.sat.python.cp_model.Constraint
#  |
#  |  AddAllDifferent = add_all_different(self, *expressions)
#  |
#  |  AddAllowedAssignments = add_allowed_assignments(self, variables: Sequence[Union[ForwardRef('IntVar'), numbers.Integral, int]], tuples_list: Iterable[Sequence[Union[numbers.Integral, int]]]) -> ortools.sat.python.cp_model.Constraint
#  |
#  |  AddAssumption = add_assumption(self, lit: Union[ForwardRef('IntVar'), ForwardRef('_NotBooleanVariable'), numbers.Integral, int, bool]) -> None
#  |
#  |  AddAssumptions = add_assumptions(self, literals: Iterable[Union[ForwardRef('IntVar'), ForwardRef('_NotBooleanVariable'), numbers.Integral, int, bool]]) -> None
#  |
#  |  AddAtLeastOne = add_at_least_one(self, *literals)
#  |
#  |  AddAtMostOne = add_at_most_one(self, *literals)
#  |
#  |  AddAutomaton = add_automaton(self, transition_variables: Sequence[Union[ForwardRef('IntVar'), numbers.Integral, int]], starting_state: Union[numbers.Integral, int], final_states: Sequence[Union[numbers.Integral, int]], transition_triples: Sequence[Tuple[Union[numbers.Integral, int], Union[numbers.Integral, int], Union[numbers.Integral, int]]]) -> ortools.sat.python.cp_model.Constraint
#  |
#  |  AddBoolAnd = add_bool_and(self, *literals)
#  |
#  |  AddBoolOr = add_bool_or(self, *literals)
#  |
#  |  AddBoolXOr = add_bool_xor(self, *literals)
#  |
#  |  AddCircuit = add_circuit(self, arcs: Sequence[Tuple[Union[numbers.Integral, int], Union[numbers.Integral, int], Union[ForwardRef('IntVar'), ForwardRef('_NotBooleanVariable'), numbers.Integral, int, bool]]]) -> ortools.sat.python.cp_model.Constraint
#  |
#  |  AddCumulative = add_cumulative(self, intervals: Iterable[ortools.sat.python.cp_model.IntervalVar], demands: Iterable[Union[ForwardRef('LinearExpr'), ForwardRef('IntVar'), numbers.Integral, int]], capacity: Union[ForwardRef('LinearExpr'), ForwardRef('IntVar'), numbers.Integral, int]) -> ortools.sat.python.cp_model.Constraint
#  |
#  |  AddDecisionStrategy = add_decision_strategy(self, variables: Sequence[ortools.sat.python.cp_model.IntVar], var_strategy: <google.protobuf.internal.enum_type_wrapper.EnumTypeWrapper object at 0x0000021BD0FCE470>, domain_strategy: <google.protobuf.internal.enum_type_wrapper.EnumTypeWrapper object at 0x0000021BD0FCEBF0>) -> None
#  |
#  |  AddDivisionEquality = add_division_equality(self, target: Union[ForwardRef('LinearExpr'), ForwardRef('IntVar'), numbers.Integral, int], num: Union[ForwardRef('LinearExpr'), ForwardRef('IntVar'), numbers.Integral, int], denom: Union[ForwardRef('LinearExpr'), ForwardRef('IntVar'), numbers.Integral, int]) -> ortools.sat.python.cp_model.Constraint
#  |
#  |  AddElement = add_element(self, index: Union[ForwardRef('IntVar'), numbers.Integral, int], variables: Sequence[Union[ForwardRef('IntVar'), numbers.Integral, int]], target: Union[ForwardRef('IntVar'), numbers.Integral, int]) -> ortools.sat.python.cp_model.Constraint
#  |
#  |  AddExactlyOne = add_exactly_one(self, *literals)
#  |
#  |  AddForbiddenAssignments = add_forbidden_assignments(self, variables: Sequence[Union[ForwardRef('IntVar'), numbers.Integral, int]], tuples_list: Iterable[Sequence[Union[numbers.Integral, int]]]) -> ortools.sat.python.cp_model.Constraint
#  |
#  |  AddHint = add_hint(self, var: ortools.sat.python.cp_model.IntVar, value: int) -> None
#  |
#  |  AddImplication = add_implication(self, a: Union[ForwardRef('IntVar'), ForwardRef('_NotBooleanVariable'), numbers.Integral, int, bool], b: Union[ForwardRef('IntVar'), ForwardRef('_NotBooleanVariable'), numbers.Integral, int, bool]) -> ortools.sat.python.cp_model.Constraint
#  |
#  |  AddInverse = add_inverse(self, variables: Sequence[Union[ForwardRef('IntVar'), numbers.Integral, int]], inverse_variables: Sequence[Union[ForwardRef('IntVar'), numbers.Integral, int]]) -> ortools.sat.python.cp_model.Constraint
#  |
#  |  AddLinearConstraint = add_linear_constraint(self, linear_expr: Union[ForwardRef('LinearExpr'), ForwardRef('IntVar'), numbers.Integral, int], lb: Union[numbers.Integral, int], ub: Union[numbers.Integral, int]) -> ortools.sat.python.cp_model.Constraint
#  |
#  |  AddLinearExpressionInDomain = add_linear_expression_in_domain(self, linear_expr: Union[ForwardRef('LinearExpr'), ForwardRef('IntVar'), numbers.Integral, int], domain: ortools.util.python.sorted_interval_list.Domain) -> ortools.sat.python.cp_model.Constraint
#  |
#  |  AddMaxEquality = add_max_equality(self, target: Union[ForwardRef('LinearExpr'), ForwardRef('IntVar'), numbers.Integral, int], exprs: Iterable[Union[ForwardRef('LinearExpr'), ForwardRef('IntVar'), numbers.Integral, int]]) -> ortools.sat.python.cp_model.Constraint
#  |
#  |  AddMinEquality = add_min_equality(self, target: Union[ForwardRef('LinearExpr'), ForwardRef('IntVar'), numbers.Integral, int], exprs: Iterable[Union[ForwardRef('LinearExpr'), ForwardRef('IntVar'), numbers.Integral, int]]) -> ortools.sat.python.cp_model.Constraint
#  |
#  |  AddModuloEquality = add_modulo_equality(self, target: Union[ForwardRef('LinearExpr'), ForwardRef('IntVar'), numbers.Integral, int], expr: Union[ForwardRef('LinearExpr'), ForwardRef('IntVar'), numbers.Integral, int], mod: Union[ForwardRef('LinearExpr'), ForwardRef('IntVar'), numbers.Integral, int]) -> ortools.sat.python.cp_model.Constraint
#  |
#  |  AddMultipleCircuit = add_multiple_circuit(self, arcs: Sequence[Tuple[Union[numbers.Integral, int], Union[numbers.Integral, int], Union[ForwardRef('IntVar'), ForwardRef('_NotBooleanVariable'), numbers.Integral, int, bool]]]) -> ortools.sat.python.cp_model.Constraint
#  |
#  |  AddMultiplicationEquality = add_multiplication_equality(self, target: Union[ForwardRef('LinearExpr'), ForwardRef('IntVar'), numbers.Integral, int], *expressions: Union[Iterable[Union[ForwardRef('LinearExpr'), ForwardRef('IntVar'), numbers.Integral, int]], ForwardRef('LinearExpr'), ForwardRef('IntVar'), numbers.Integral, int]) -> ortools.sat.python.cp_model.Constraint
#  |
#  |  AddNoOverlap = add_no_overlap(self, interval_vars: Iterable[ortools.sat.python.cp_model.IntervalVar]) -> ortools.sat.python.cp_model.Constraint
#  |
#  |  AddNoOverlap2D = add_no_overlap_2d(self, x_intervals: Iterable[ortools.sat.python.cp_model.IntervalVar], y_intervals: Iterable[ortools.sat.python.cp_model.IntervalVar]) -> ortools.sat.python.cp_model.Constraint
#  |
#  |  AddReservoirConstraint = add_reservoir_constraint(self, times: Iterable[Union[ForwardRef('LinearExpr'), ForwardRef('IntVar'), numbers.Integral, int]], level_changes: Iterable[Union[ForwardRef('LinearExpr'), ForwardRef('IntVar'), numbers.Integral, int]], min_level: int, max_level: int) -> ortools.sat.python.cp_model.Constraint
#  |
#  |  ClearAssumptions = clear_assumptions(self) -> None
#  |
#  |  ClearHints = clear_hints(self)
#  |
#  |  ClearObjective = clear_objective(self)
#  |
#  |  Clone = clone(self) -> 'CpModel'
#  |
#  |  ExportToFile = export_to_file(self, file: str) -> bool
#  |
#  |  GetBoolVarFromProtoIndex = get_bool_var_from_proto_index(self, index: int) -> ortools.sat.python.cp_model.IntVar
#  |
#  |  GetIntVarFromProtoIndex = get_int_var_from_proto_index(self, index: int) -> ortools.sat.python.cp_model.IntVar
#  |
#  |  GetIntervalVarFromProtoIndex = get_interval_var_from_proto_index(self, index: int) -> ortools.sat.python.cp_model.IntervalVar
#  |
#  |  HasObjective = has_objective(self) -> bool
#  |
#  |  Maximize = maximize(self, obj: Union[ForwardRef('LinearExpr'), ForwardRef('IntVar'), numbers.Integral, int, numbers.Number, float])
#  |
#  |  Minimize = minimize(self, obj: Union[ForwardRef('LinearExpr'), ForwardRef('IntVar'), numbers.Integral, int, numbers.Number, float])
#  |
#  |  ModelStats = model_stats(self) -> str
#  |
#  |  Name(self) -> str
#  |
#  |  NewBoolVar = new_bool_var(self, name: str) -> ortools.sat.python.cp_model.IntVar
#  |
#  |  NewBoolVarSeries = new_bool_var_series(self, name: str, index: pandas.core.indexes.base.Index) -> pandas.core.series.Series
#  |
#  |  NewConstant = new_constant(self, value: Union[numbers.Integral, int]) -> ortools.sat.python.cp_model.IntVar
#  |
#  |  NewFixedSizedIntervalVar = new_fixed_size_interval_var(self, start: Union[ForwardRef('LinearExpr'), ForwardRef('IntVar'), numbers.Integral, int], size: Union[numbers.Integral, int], name: str) -> ortools.sat.python.cp_model.IntervalVar
#  |
#  |  NewIntVar = new_int_var(self, lb: Union[numbers.Integral, int], ub: Union[numbers.Integral, int], name: str) -> ortools.sat.python.cp_model.IntVar
#  |
#  |  NewIntVarFromDomain = new_int_var_from_domain(self, domain: ortools.util.python.sorted_interval_list.Domain, name: str) -> ortools.sat.python.cp_model.IntVar
#  |
#  |  NewIntVarSeries = new_int_var_series(self, name: str, index: pandas.core.indexes.base.Index, lower_bounds: Union[numbers.Integral, int, pandas.core.series.Series], upper_bounds: Union[numbers.Integral, int, pandas.core.series.Series]) -> pandas.core.series.Series
#  |
#  |  NewIntervalVar = new_interval_var(self, start: Union[ForwardRef('LinearExpr'), ForwardRef('IntVar'), numbers.Integral, int], size: Union[ForwardRef('LinearExpr'), ForwardRef('IntVar'), numbers.Integral, int], end: Union[ForwardRef('LinearExpr'), ForwardRef('IntVar'), numbers.Integral, int], name: str) -> ortools.sat.python.cp_model.IntervalVar
#  |
#  |  NewIntervalVarSeries = new_interval_var_series(self, name: str, index: pandas.core.indexes.base.Index, starts: Union[ForwardRef('LinearExpr'), ForwardRef('IntVar'), numbers.Integral, int, pandas.core.series.Series], sizes: Union[ForwardRef('LinearExpr'), ForwardRef('IntVar'), numbers.Integral, int, pandas.core.series.Series], ends: Union[ForwardRef('LinearExpr'), ForwardRef('IntVar'), numbers.Integral, int, pandas.core.series.Series]) -> pandas.core.series.Series
#  |
#  |  NewOptionalFixedSizedIntervalVar = new_optional_fixed_size_interval_var(self, start: Union[ForwardRef('LinearExpr'), ForwardRef('IntVar'), numbers.Integral, int], size: Union[numbers.Integral, int], is_present: Union[ForwardRef('IntVar'), ForwardRef('_NotBooleanVariable'), numbers.Integral, int, bool], name: str) -> ortools.sat.python.cp_model.IntervalVar
#  |
#  |  NewOptionalFixedSizedIntervalVarSeries = new_optional_fixed_size_interval_var_series(self, name: str, index: pandas.core.indexes.base.Index, starts: Union[ForwardRef('LinearExpr'), ForwardRef('IntVar'), numbers.Integral, int, pandas.core.series.Series], sizes: Union[numbers.Integral, int, pandas.core.series.Series], are_present: Union[ForwardRef('IntVar'), ForwardRef('_NotBooleanVariable'), numbers.Integral, int, bool, pandas.core.series.Series]) -> pandas.core.series.Series
#  |
#  |  NewOptionalIntervalVar = new_optional_interval_var(self, start: Union[ForwardRef('LinearExpr'), ForwardRef('IntVar'), numbers.Integral, int], size: Union[ForwardRef('LinearExpr'), ForwardRef('IntVar'), numbers.Integral, int], end: Union[ForwardRef('LinearExpr'), ForwardRef('IntVar'), numbers.Integral, int], is_present: Union[ForwardRef('IntVar'), ForwardRef('_NotBooleanVariable'), numbers.Integral, int, bool], name: str) -> ortools.sat.python.cp_model.IntervalVar
#  |
#  |  NewOptionalIntervalVarSeries = new_optional_interval_var_series(self, name: str, index: pandas.core.indexes.base.Index, starts: Union[ForwardRef('LinearExpr'), ForwardRef('IntVar'), numbers.Integral, int, pandas.core.series.Series], sizes: Union[ForwardRef('LinearExpr'), ForwardRef('IntVar'), numbers.Integral, int, pandas.core.series.Series], ends: Union[ForwardRef('LinearExpr'), ForwardRef('IntVar'), numbers.Integral, int, pandas.core.series.Series], are_present: Union[ForwardRef('IntVar'), ForwardRef('_NotBooleanVariable'), numbers.Integral, int, bool, pandas.core.series.Series]) -> pandas.core.series.Series
#  |
#  |  Proto(self) -> ortools.sat.cp_model_pb2.CpModelProto
#  |
#  |  SetName(self, name: str) -> None
#  |
#  |  Validate = validate(self) -> str
#  |
#  |  __init__(self)
#  |      Initialize self.  See help(type(self)) for accurate signature.
#  |
#  |  __str__(self)
#  |      Return str(self).
#  |
#  |  add(self, ct: Union[ortools.sat.python.cp_model.BoundedLinearExpression, bool]) -> ortools.sat.python.cp_model.Constraint
#  |      Adds a `BoundedLinearExpression` to the model.
#  |
#  |      Args:
#  |        ct: A [`BoundedLinearExpression`](#boundedlinearexpression).
#  |
#  |      Returns:
#  |        An instance of the `Constraint` class.
#  |
#  |  add_abs_equality(self, target: Union[ForwardRef('LinearExpr'), ForwardRef('IntVar'), numbers.Integral, int], expr: Union[ForwardRef('LinearExpr'), ForwardRef('IntVar'), numbers.Integral, int]) -> ortools.sat.python.cp_model.Constraint
#  |      Adds `target == Abs(expr)`.
#  |
#  |  add_all_different(self, *expressions)
#  |      Adds AllDifferent(expressions).
#  |
#  |      This constraint forces all expressions to have different values.
#  |
#  |      Args:
#  |        *expressions: simple expressions of the form a * var + constant.
#  |
#  |      Returns:
#  |        An instance of the `Constraint` class.
#  |
#  |  add_allowed_assignments(self, variables: Sequence[Union[ForwardRef('IntVar'), numbers.Integral, int]], tuples_list: Iterable[Sequence[Union[numbers.Integral, int]]]) -> ortools.sat.python.cp_model.Constraint
#  |      Adds AllowedAssignments(variables, tuples_list).
#  |
#  |      An AllowedAssignments constraint is a constraint on an array of variables,
#  |      which requires that when all variables are assigned values, the resulting
#  |      array equals one of the  tuples in `tuple_list`.
#  |
#  |      Args:
#  |        variables: A list of variables.
#  |        tuples_list: A list of admissible tuples. Each tuple must have the same
#  |          length as the variables, and the ith value of a tuple corresponds to the
#  |          ith variable.
#  |
#  |      Returns:
#  |        An instance of the `Constraint` class.
#  |
#  |      Raises:
#  |        TypeError: If a tuple does not have the same size as the list of
#  |            variables.
#  |        ValueError: If the array of variables is empty.
#  |
#  |  add_assumption(self, lit: Union[ForwardRef('IntVar'), ForwardRef('_NotBooleanVariable'), numbers.Integral, int, bool]) -> None
#  |      Adds the literal to the model as assumptions.
#  |
#  |  add_assumptions(self, literals: Iterable[Union[ForwardRef('IntVar'), ForwardRef('_NotBooleanVariable'), numbers.Integral, int, bool]]) -> None
#  |      Adds the literals to the model as assumptions.
#  |
#  |  add_at_least_one(self, *literals)
#  |      Same as `add_bool_or`: `sum(literals) >= 1`.
#  |
#  |  add_at_most_one(self, *literals)
#  |      Adds `AtMostOne(literals)`: `sum(literals) <= 1`.
#  |
#  |  add_automaton(self, transition_variables: Sequence[Union[ForwardRef('IntVar'), numbers.Integral, int]], starting_state: Union[numbers.Integral, int], final_states: Sequence[Union[numbers.Integral, int]], transition_triples: Sequence[Tuple[Union[numbers.Integral, int], Union[numbers.Integral, int], Union[numbers.Integral, int]]]) -> ortools.sat.python.cp_model.Constraint
#  |      Adds an automaton constraint.
#  |
#  |      An automaton constraint takes a list of variables (of size *n*), an initial
#  |      state, a set of final states, and a set of transitions. A transition is a
#  |      triplet (*tail*, *transition*, *head*), where *tail* and *head* are states,
#  |      and *transition* is the label of an arc from *head* to *tail*,
#  |      corresponding to the value of one variable in the list of variables.
#  |
#  |      This automaton will be unrolled into a flow with *n* + 1 phases. Each phase
#  |      contains the possible states of the automaton. The first state contains the
#  |      initial state. The last phase contains the final states.
#  |
#  |      Between two consecutive phases *i* and *i* + 1, the automaton creates a set
#  |      of arcs. For each transition (*tail*, *transition*, *head*), it will add
#  |      an arc from the state *tail* of phase *i* and the state *head* of phase
#  |      *i* + 1. This arc is labeled by the value *transition* of the variables
#  |      `variables[i]`. That is, this arc can only be selected if `variables[i]`
#  |      is assigned the value *transition*.
#  |
#  |      A feasible solution of this constraint is an assignment of variables such
#  |      that, starting from the initial state in phase 0, there is a path labeled by
#  |      the values of the variables that ends in one of the final states in the
#  |      final phase.
#  |
#  |      Args:
#  |        transition_variables: A non-empty list of variables whose values
#  |          correspond to the labels of the arcs traversed by the automaton.
#  |        starting_state: The initial state of the automaton.
#  |        final_states: A non-empty list of admissible final states.
#  |        transition_triples: A list of transitions for the automaton, in the
#  |          following format (current_state, variable_value, next_state).
#  |
#  |      Returns:
#  |        An instance of the `Constraint` class.
#  |
#  |      Raises:
#  |        ValueError: if `transition_variables`, `final_states`, or
#  |          `transition_triples` are empty.
#  |
#  |  add_bool_and(self, *literals)
#  |      Adds `And(literals) == true`.
#  |
#  |  add_bool_or(self, *literals)
#  |      Adds `Or(literals) == true`: sum(literals) >= 1.
#  |
#  |  add_bool_xor(self, *literals)
#  |      Adds `XOr(literals) == true`.
#  |
#  |      In contrast to add_bool_or and add_bool_and, it does not support
#  |          .only_enforce_if().
#  |
#  |      Args:
#  |        *literals: the list of literals in the constraint.
#  |
#  |      Returns:
#  |        An `Constraint` object.
#  |
#  |  add_circuit(self, arcs: Sequence[Tuple[Union[numbers.Integral, int], Union[numbers.Integral, int], Union[ForwardRef('IntVar'), ForwardRef('_NotBooleanVariable'), numbers.Integral, int, bool]]]) -> ortools.sat.python.cp_model.Constraint
#  |      Adds Circuit(arcs).
#  |
#  |      Adds a circuit constraint from a sparse list of arcs that encode the graph.
#  |
#  |      A circuit is a unique Hamiltonian path in a subgraph of the total
#  |      graph. In case a node 'i' is not in the path, then there must be a
#  |      loop arc 'i -> i' associated with a true literal. Otherwise
#  |      this constraint will fail.
#  |
#  |      Args:
#  |        arcs: a list of arcs. An arc is a tuple (source_node, destination_node,
#  |          literal). The arc is selected in the circuit if the literal is true.
#  |          Both source_node and destination_node must be integers between 0 and the
#  |          number of nodes - 1.
#  |
#  |      Returns:
#  |        An instance of the `Constraint` class.
#  |
#  |      Raises:
#  |        ValueError: If the list of arcs is empty.
#  |
#  |  add_cumulative(self, intervals: Iterable[ortools.sat.python.cp_model.IntervalVar], demands: Iterable[Union[ForwardRef('LinearExpr'), ForwardRef('IntVar'), numbers.Integral, int]], capacity: Union[ForwardRef('LinearExpr'), ForwardRef('IntVar'), numbers.Integral, int]) -> ortools.sat.python.cp_model.Constraint
#  |      Adds Cumulative(intervals, demands, capacity).
#  |
#  |      This constraint enforces that:
#  |
#  |          for all t:
#  |            sum(demands[i]
#  |              if (start(intervals[i]) <= t < end(intervals[i])) and
#  |              (intervals[i] is present)) <= capacity
#  |
#  |      Args:
#  |        intervals: The list of intervals.
#  |        demands: The list of demands for each interval. Each demand must be >= 0.
#  |          Each demand can be a 1-var affine expression (a * x + b).
#  |        capacity: The maximum capacity of the cumulative constraint. It can be a
#  |          1-var affine expression (a * x + b).
#  |
#  |      Returns:
#  |        An instance of the `Constraint` class.
#  |
#  |  add_decision_strategy(self, variables: Sequence[ortools.sat.python.cp_model.IntVar], var_strategy: <google.protobuf.internal.enum_type_wrapper.EnumTypeWrapper object at 0x0000021BD0FCE470>, domain_strategy: <google.protobuf.internal.enum_type_wrapper.EnumTypeWrapper object at 0x0000021BD0FCEBF0>) -> None
#  |      Adds a search strategy to the model.
#  |
#  |      Args:
#  |        variables: a list of variables this strategy will assign.
#  |        var_strategy: heuristic to choose the next variable to assign.
#  |        domain_strategy: heuristic to reduce the domain of the selected variable.
#  |          Currently, this is advanced code: the union of all strategies added to
#  |          the model must be complete, i.e. instantiates all variables. Otherwise,
#  |          solve() will fail.
#  |
#  |  add_division_equality(self, target: Union[ForwardRef('LinearExpr'), ForwardRef('IntVar'), numbers.Integral, int], num: Union[ForwardRef('LinearExpr'), ForwardRef('IntVar'), numbers.Integral, int], denom: Union[ForwardRef('LinearExpr'), ForwardRef('IntVar'), numbers.Integral, int]) -> ortools.sat.python.cp_model.Constraint
#  |      Adds `target == num // denom` (integer division rounded towards 0).
#  |
#  |  add_element(self, index: Union[ForwardRef('IntVar'), numbers.Integral, int], variables: Sequence[Union[ForwardRef('IntVar'), numbers.Integral, int]], target: Union[ForwardRef('IntVar'), numbers.Integral, int]) -> ortools.sat.python.cp_model.Constraint
#  |      Adds the element constraint: `variables[index] == target`.
#  |
#  |      Args:
#  |        index: The index of the variable that's being constrained.
#  |        variables: A list of variables.
#  |        target: The value that the variable must be equal to.
#  |
#  |      Returns:
#  |        An instance of the `Constraint` class.
#  |
#  |  add_exactly_one(self, *literals)
#  |      Adds `ExactlyOne(literals)`: `sum(literals) == 1`.
#  |
#  |  add_forbidden_assignments(self, variables: Sequence[Union[ForwardRef('IntVar'), numbers.Integral, int]], tuples_list: Iterable[Sequence[Union[numbers.Integral, int]]]) -> ortools.sat.python.cp_model.Constraint
#  |      Adds add_forbidden_assignments(variables, [tuples_list]).
#  |
#  |      A ForbiddenAssignments constraint is a constraint on an array of variables
#  |      where the list of impossible combinations is provided in the tuples list.
#  |
#  |      Args:
#  |        variables: A list of variables.
#  |        tuples_list: A list of forbidden tuples. Each tuple must have the same
#  |          length as the variables, and the *i*th value of a tuple corresponds to
#  |          the *i*th variable.
#  |
#  |      Returns:
#  |        An instance of the `Constraint` class.
#  |
#  |      Raises:
#  |        TypeError: If a tuple does not have the same size as the list of
#  |                   variables.
#  |        ValueError: If the array of variables is empty.
#  |
#  |  add_hint(self, var: ortools.sat.python.cp_model.IntVar, value: int) -> None
#  |      Adds 'var == value' as a hint to the solver.
#  |
#  |  add_implication(self, a: Union[ForwardRef('IntVar'), ForwardRef('_NotBooleanVariable'), numbers.Integral, int, bool], b: Union[ForwardRef('IntVar'), ForwardRef('_NotBooleanVariable'), numbers.Integral, int, bool]) -> ortools.sat.python.cp_model.Constraint
#  |      Adds `a => b` (`a` implies `b`).
#  |
#  |  add_inverse(self, variables: Sequence[Union[ForwardRef('IntVar'), numbers.Integral, int]], inverse_variables: Sequence[Union[ForwardRef('IntVar'), numbers.Integral, int]]) -> ortools.sat.python.cp_model.Constraint
#  |      Adds Inverse(variables, inverse_variables).
#  |
#  |      An inverse constraint enforces that if `variables[i]` is assigned a value
#  |      `j`, then `inverse_variables[j]` is assigned a value `i`. And vice versa.
#  |
#  |      Args:
#  |        variables: An array of integer variables.
#  |        inverse_variables: An array of integer variables.
#  |
#  |      Returns:
#  |        An instance of the `Constraint` class.
#  |
#  |      Raises:
#  |        TypeError: if variables and inverse_variables have different lengths, or
#  |            if they are empty.
#  |
#  |  add_linear_constraint(self, linear_expr: Union[ForwardRef('LinearExpr'), ForwardRef('IntVar'), numbers.Integral, int], lb: Union[numbers.Integral, int], ub: Union[numbers.Integral, int]) -> ortools.sat.python.cp_model.Constraint
#  |      Adds the constraint: `lb <= linear_expr <= ub`.
#  |
#  |  add_linear_expression_in_domain(self, linear_expr: Union[ForwardRef('LinearExpr'), ForwardRef('IntVar'), numbers.Integral, int], domain: ortools.util.python.sorted_interval_list.Domain) -> ortools.sat.python.cp_model.Constraint
#  |      Adds the constraint: `linear_expr` in `domain`.
#  |
#  |  add_map_domain(self, var: ortools.sat.python.cp_model.IntVar, bool_var_array: Iterable[ortools.sat.python.cp_model.IntVar], offset: Union[numbers.Integral, int] = 0)
#  |      Adds `var == i + offset <=> bool_var_array[i] == true for all i`.
#  |
#  |  add_max_equality(self, target: Union[ForwardRef('LinearExpr'), ForwardRef('IntVar'), numbers.Integral, int], exprs: Iterable[Union[ForwardRef('LinearExpr'), ForwardRef('IntVar'), numbers.Integral, int]]) -> ortools.sat.python.cp_model.Constraint
#  |      Adds `target == Max(exprs)`.
#  |
#  |  add_min_equality(self, target: Union[ForwardRef('LinearExpr'), ForwardRef('IntVar'), numbers.Integral, int], exprs: Iterable[Union[ForwardRef('LinearExpr'), ForwardRef('IntVar'), numbers.Integral, int]]) -> ortools.sat.python.cp_model.Constraint
#  |      Adds `target == Min(exprs)`.
#  |
#  |  add_modulo_equality(self, target: Union[ForwardRef('LinearExpr'), ForwardRef('IntVar'), numbers.Integral, int], expr: Union[ForwardRef('LinearExpr'), ForwardRef('IntVar'), numbers.Integral, int], mod: Union[ForwardRef('LinearExpr'), ForwardRef('IntVar'), numbers.Integral, int]) -> ortools.sat.python.cp_model.Constraint
#  |      Adds `target = expr % mod`.
#  |
#  |  add_multiple_circuit(self, arcs: Sequence[Tuple[Union[numbers.Integral, int], Union[numbers.Integral, int], Union[ForwardRef('IntVar'), ForwardRef('_NotBooleanVariable'), numbers.Integral, int, bool]]]) -> ortools.sat.python.cp_model.Constraint
#  |      Adds a multiple circuit constraint, aka the 'VRP' constraint.
#  |
#  |      The direct graph where arc #i (from tails[i] to head[i]) is present iff
#  |      literals[i] is true must satisfy this set of properties:
#  |      - #incoming arcs == 1 except for node 0.
#  |      - #outgoing arcs == 1 except for node 0.
#  |      - for node zero, #incoming arcs == #outgoing arcs.
#  |      - There are no duplicate arcs.
#  |      - Self-arcs are allowed except for node 0.
#  |      - There is no cycle in this graph, except through node 0.
#  |
#  |      Args:
#  |        arcs: a list of arcs. An arc is a tuple (source_node, destination_node,
#  |          literal). The arc is selected in the circuit if the literal is true.
#  |          Both source_node and destination_node must be integers between 0 and the
#  |          number of nodes - 1.
#  |
#  |      Returns:
#  |        An instance of the `Constraint` class.
#  |
#  |      Raises:
#  |        ValueError: If the list of arcs is empty.
#  |
#  |  add_multiplication_equality(self, target: Union[ForwardRef('LinearExpr'), ForwardRef('IntVar'), numbers.Integral, int], *expressions: Union[Iterable[Union[ForwardRef('LinearExpr'), ForwardRef('IntVar'), numbers.Integral, int]], ForwardRef('LinearExpr'), ForwardRef('IntVar'), numbers.Integral, int]) -> ortools.sat.python.cp_model.Constraint
#  |      Adds `target == expressions[0] * .. * expressions[n]`.
#  |
#  |  add_no_overlap(self, interval_vars: Iterable[ortools.sat.python.cp_model.IntervalVar]) -> ortools.sat.python.cp_model.Constraint
#  |      Adds NoOverlap(interval_vars).
#  |
#  |      A NoOverlap constraint ensures that all present intervals do not overlap
#  |      in time.
#  |
#  |      Args:
#  |        interval_vars: The list of interval variables to constrain.
#  |
#  |      Returns:
#  |        An instance of the `Constraint` class.
#  |
#  |  add_no_overlap_2d(self, x_intervals: Iterable[ortools.sat.python.cp_model.IntervalVar], y_intervals: Iterable[ortools.sat.python.cp_model.IntervalVar]) -> ortools.sat.python.cp_model.Constraint
#  |      Adds NoOverlap2D(x_intervals, y_intervals).
#  |
#  |      A NoOverlap2D constraint ensures that all present rectangles do not overlap
#  |      on a plane. Each rectangle is aligned with the X and Y axis, and is defined
#  |      by two intervals which represent its projection onto the X and Y axis.
#  |
#  |      Furthermore, one box is optional if at least one of the x or y interval is
#  |      optional.
#  |
#  |      Args:
#  |        x_intervals: The X coordinates of the rectangles.
#  |        y_intervals: The Y coordinates of the rectangles.
#  |
#  |      Returns:
#  |        An instance of the `Constraint` class.
#  |
#  |  add_reservoir_constraint(self, times: Iterable[Union[ForwardRef('LinearExpr'), ForwardRef('IntVar'), numbers.Integral, int]], level_changes: Iterable[Union[ForwardRef('LinearExpr'), ForwardRef('IntVar'), numbers.Integral, int]], min_level: int, max_level: int) -> ortools.sat.python.cp_model.Constraint
#  |      Adds Reservoir(times, level_changes, min_level, max_level).
#  |
#  |      Maintains a reservoir level within bounds. The water level starts at 0, and
#  |      at any time, it must be between min_level and max_level.
#  |
#  |      If the affine expression `times[i]` is assigned a value t, then the current
#  |      level changes by `level_changes[i]`, which is constant, at time t.
#  |
#  |       Note that min level must be <= 0, and the max level must be >= 0. Please
#  |       use fixed level_changes to simulate initial state.
#  |
#  |       Therefore, at any time:
#  |           sum(level_changes[i] if times[i] <= t) in [min_level, max_level]
#  |
#  |      Args:
#  |        times: A list of 1-var affine expressions (a * x + b) which specify the
#  |          time of the filling or emptying the reservoir.
#  |        level_changes: A list of integer values that specifies the amount of the
#  |          emptying or filling. Currently, variable demands are not supported.
#  |        min_level: At any time, the level of the reservoir must be greater or
#  |          equal than the min level.
#  |        max_level: At any time, the level of the reservoir must be less or equal
#  |          than the max level.
#  |
#  |      Returns:
#  |        An instance of the `Constraint` class.
#  |
#  |      Raises:
#  |        ValueError: if max_level < min_level.
#  |
#  |        ValueError: if max_level < 0.
#  |
#  |        ValueError: if min_level > 0
#  |
#  |  add_reservoir_constraint_with_active(self, times: Iterable[Union[ForwardRef('LinearExpr'), ForwardRef('IntVar'), numbers.Integral, int]], level_changes: Iterable[Union[ForwardRef('LinearExpr'), ForwardRef('IntVar'), numbers.Integral, int]], actives: Iterable[Union[ForwardRef('IntVar'), ForwardRef('_NotBooleanVariable'), numbers.Integral, int, bool]], min_level: int, max_level: int) -> ortools.sat.python.cp_model.Constraint
#  |      Adds Reservoir(times, level_changes, actives, min_level, max_level).
#  |
#  |      Maintains a reservoir level within bounds. The water level starts at 0, and
#  |      at any time, it must be between min_level and max_level.
#  |
#  |      If the variable `times[i]` is assigned a value t, and `actives[i]` is
#  |      `True`, then the current level changes by `level_changes[i]`, which is
#  |      constant,
#  |      at time t.
#  |
#  |       Note that min level must be <= 0, and the max level must be >= 0. Please
#  |       use fixed level_changes to simulate initial state.
#  |
#  |       Therefore, at any time:
#  |           sum(level_changes[i] * actives[i] if times[i] <= t) in [min_level,
#  |           max_level]
#  |
#  |
#  |      The array of boolean variables 'actives', if defined, indicates which
#  |      actions are actually performed.
#  |
#  |      Args:
#  |        times: A list of 1-var affine expressions (a * x + b) which specify the
#  |          time of the filling or emptying the reservoir.
#  |        level_changes: A list of integer values that specifies the amount of the
#  |          emptying or filling. Currently, variable demands are not supported.
#  |        actives: a list of boolean variables. They indicates if the
#  |          emptying/refilling events actually take place.
#  |        min_level: At any time, the level of the reservoir must be greater or
#  |          equal than the min level.
#  |        max_level: At any time, the level of the reservoir must be less or equal
#  |          than the max level.
#  |
#  |      Returns:
#  |        An instance of the `Constraint` class.
#  |
#  |      Raises:
#  |        ValueError: if max_level < min_level.
#  |
#  |        ValueError: if max_level < 0.
#  |
#  |        ValueError: if min_level > 0
#  |
#  |  assert_is_boolean_variable(self, x: Union[ForwardRef('IntVar'), ForwardRef('_NotBooleanVariable'), numbers.Integral, int, bool]) -> None
#  |      # Helpers.
#  |
#  |  clear_assumptions(self) -> None
#  |      Removes all assumptions from the model.
#  |
#  |  clear_hints(self)
#  |      Removes any solution hint from the model.
#  |
#  |  clear_objective(self)
#  |
#  |  clone(self) -> 'CpModel'
#  |      Reset the model, and creates a new one from a CpModelProto instance.
#  |
#  |  export_to_file(self, file: str) -> bool
#  |      Write the model as a protocol buffer to 'file'.
#  |
#  |      Args:
#  |        file: file to write the model to. If the filename ends with 'txt', the
#  |          model will be written as a text file, otherwise, the binary format will
#  |          be used.
#  |
#  |      Returns:
#  |        True if the model was correctly written.
#  |
#  |  get_bool_var_from_proto_index(self, index: int) -> ortools.sat.python.cp_model.IntVar
#  |      Returns an already created Boolean variable from its index.
#  |
#  |  get_int_var_from_proto_index(self, index: int) -> ortools.sat.python.cp_model.IntVar
#  |      Returns an already created integer variable from its index.
#  |
#  |  get_interval_index(self, arg: ortools.sat.python.cp_model.IntervalVar) -> int
#  |
#  |  get_interval_var_from_proto_index(self, index: int) -> ortools.sat.python.cp_model.IntervalVar
#  |      Returns an already created interval variable from its index.
#  |
#  |  get_or_make_boolean_index(self, arg: Union[ForwardRef('IntVar'), ForwardRef('_NotBooleanVariable'), numbers.Integral, int, bool]) -> int
#  |      Returns an index from a boolean expression.
#  |
#  |  get_or_make_index(self, arg: Union[ForwardRef('IntVar'), numbers.Integral, int]) -> int
#  |      Returns the index of a variable, its negation, or a number.
#  |
#  |  get_or_make_index_from_constant(self, value: Union[numbers.Integral, int]) -> int
#  |
#  |  has_objective(self) -> bool
#  |
#  |  maximize(self, obj: Union[ForwardRef('LinearExpr'), ForwardRef('IntVar'), numbers.Integral, int, numbers.Number, float])
#  |      Sets the objective of the model to maximize(obj).
#  |
#  |  minimize(self, obj: Union[ForwardRef('LinearExpr'), ForwardRef('IntVar'), numbers.Integral, int, numbers.Number, float])
#  |      Sets the objective of the model to minimize(obj).
#  |
#  |  model_stats(self) -> str
#  |      Returns a string containing some model statistics.
#  |
#  |  negated(self, index: int) -> int
#  |
#  |  new_bool_var(self, name: str) -> ortools.sat.python.cp_model.IntVar
#  |      Creates a 0-1 variable with the given name.
#  |
#  |  new_bool_var_series(self, name: str, index: pandas.core.indexes.base.Index) -> pandas.core.series.Series
#  |      Creates a series of (scalar-valued) variables with the given name.
#  |
#  |      Args:
#  |        name (str): Required. The name of the variable set.
#  |        index (pd.Index): Required. The index to use for the variable set.
#  |
#  |      Returns:
#  |        pd.Series: The variable set indexed by its corresponding dimensions.
#  |
#  |      Raises:
#  |        TypeError: if the `index` is invalid (e.g. a `DataFrame`).
#  |        ValueError: if the `name` is not a valid identifier or already exists.
#  |
#  |  new_constant(self, value: Union[numbers.Integral, int]) -> ortools.sat.python.cp_model.IntVar
#  |      Declares a constant integer.
#  |
#  |  new_fixed_size_interval_var(self, start: Union[ForwardRef('LinearExpr'), ForwardRef('IntVar'), numbers.Integral, int], size: Union[numbers.Integral, int], name: str) -> ortools.sat.python.cp_model.IntervalVar
#  |      Creates an interval variable from start, and a fixed size.
#  |
#  |      An interval variable is a constraint, that is itself used in other
#  |      constraints like NoOverlap.
#  |
#  |      Args:
#  |        start: The start of the interval. It must be of the form a * var + b.
#  |        size: The size of the interval. It must be an integer value.
#  |        name: The name of the interval variable.
#  |
#  |      Returns:
#  |        An `IntervalVar` object.
#  |
#  |  new_fixed_size_interval_var_series(self, name: str, index: pandas.core.indexes.base.Index, starts: Union[ForwardRef('LinearExpr'), ForwardRef('IntVar'), numbers.Integral, int, pandas.core.series.Series], sizes: Union[numbers.Integral, int, pandas.core.series.Series]) -> pandas.core.series.Series
#  |      Creates a series of interval variables with the given name.
#  |
#  |      Args:
#  |        name (str): Required. The name of the variable set.
#  |        index (pd.Index): Required. The index to use for the variable set.
#  |        starts (Union[LinearExprT, pd.Series]): The start of each interval in the
#  |          set. If a `pd.Series` is passed in, it will be based on the
#  |          corresponding values of the pd.Series.
#  |        sizes (Union[IntegralT, pd.Series]): The fixed size of each interval in
#  |          the set. If a `pd.Series` is passed in, it will be based on the
#  |          corresponding values of the pd.Series.
#  |
#  |      Returns:
#  |        pd.Series: The interval variable set indexed by its corresponding
#  |        dimensions.
#  |
#  |      Raises:
#  |        TypeError: if the `index` is invalid (e.g. a `DataFrame`).
#  |        ValueError: if the `name` is not a valid identifier or already exists.
#  |        ValueError: if the all the indexes do not match.
#  |
#  |  new_int_var(self, lb: Union[numbers.Integral, int], ub: Union[numbers.Integral, int], name: str) -> ortools.sat.python.cp_model.IntVar
#  |      Create an integer variable with domain [lb, ub].
#  |
#  |      The CP-SAT solver is limited to integer variables. If you have fractional
#  |      values, scale them up so that they become integers; if you have strings,
#  |      encode them as integers.
#  |
#  |      Args:
#  |        lb: Lower bound for the variable.
#  |        ub: Upper bound for the variable.
#  |        name: The name of the variable.
#  |
#  |      Returns:
#  |        a variable whose domain is [lb, ub].
#  |
#  |  new_int_var_from_domain(self, domain: ortools.util.python.sorted_interval_list.Domain, name: str) -> ortools.sat.python.cp_model.IntVar
#  |      Create an integer variable from a domain.
#  |
#  |      A domain is a set of integers specified by a collection of intervals.
#  |      For example, `model.new_int_var_from_domain(cp_model.
#  |           Domain.from_intervals([[1, 2], [4, 6]]), 'x')`
#  |
#  |      Args:
#  |        domain: An instance of the Domain class.
#  |        name: The name of the variable.
#  |
#  |      Returns:
#  |          a variable whose domain is the given domain.
#  |
#  |  new_int_var_series(self, name: str, index: pandas.core.indexes.base.Index, lower_bounds: Union[numbers.Integral, int, pandas.core.series.Series], upper_bounds: Union[numbers.Integral, int, pandas.core.series.Series]) -> pandas.core.series.Series
#  |      Creates a series of (scalar-valued) variables with the given name.
#  |
#  |      Args:
#  |        name (str): Required. The name of the variable set.
#  |        index (pd.Index): Required. The index to use for the variable set.
#  |        lower_bounds (Union[int, pd.Series]): A lower bound for variables in the
#  |          set. If a `pd.Series` is passed in, it will be based on the
#  |          corresponding values of the pd.Series.
#  |        upper_bounds (Union[int, pd.Series]): An upper bound for variables in the
#  |          set. If a `pd.Series` is passed in, it will be based on the
#  |          corresponding values of the pd.Series.
#  |
#  |      Returns:
#  |        pd.Series: The variable set indexed by its corresponding dimensions.
#  |
#  |      Raises:
#  |        TypeError: if the `index` is invalid (e.g. a `DataFrame`).
#  |        ValueError: if the `name` is not a valid identifier or already exists.
#  |        ValueError: if the `lowerbound` is greater than the `upperbound`.
#  |        ValueError: if the index of `lower_bound`, or `upper_bound` does not match
#  |        the input index.
#  |
#  |  new_interval_var(self, start: Union[ForwardRef('LinearExpr'), ForwardRef('IntVar'), numbers.Integral, int], size: Union[ForwardRef('LinearExpr'), ForwardRef('IntVar'), numbers.Integral, int], end: Union[ForwardRef('LinearExpr'), ForwardRef('IntVar'), numbers.Integral, int], name: str) -> ortools.sat.python.cp_model.IntervalVar
#  |      Creates an interval variable from start, size, and end.
#  |
#  |      An interval variable is a constraint, that is itself used in other
#  |      constraints like NoOverlap.
#  |
#  |      Internally, it ensures that `start + size == end`.
#  |
#  |      Args:
#  |        start: The start of the interval. It must be of the form a * var + b.
#  |        size: The size of the interval. It must be of the form a * var + b.
#  |        end: The end of the interval. It must be of the form a * var + b.
#  |        name: The name of the interval variable.
#  |
#  |      Returns:
#  |        An `IntervalVar` object.
#  |
#  |  new_interval_var_series(self, name: str, index: pandas.core.indexes.base.Index, starts: Union[ForwardRef('LinearExpr'), ForwardRef('IntVar'), numbers.Integral, int, pandas.core.series.Series], sizes: Union[ForwardRef('LinearExpr'), ForwardRef('IntVar'), numbers.Integral, int, pandas.core.series.Series], ends: Union[ForwardRef('LinearExpr'), ForwardRef('IntVar'), numbers.Integral, int, pandas.core.series.Series]) -> pandas.core.series.Series
#  |      Creates a series of interval variables with the given name.
#  |
#  |      Args:
#  |        name (str): Required. The name of the variable set.
#  |        index (pd.Index): Required. The index to use for the variable set.
#  |        starts (Union[LinearExprT, pd.Series]): The start of each interval in the
#  |          set. If a `pd.Series` is passed in, it will be based on the
#  |          corresponding values of the pd.Series.
#  |        sizes (Union[LinearExprT, pd.Series]): The size of each interval in the
#  |          set. If a `pd.Series` is passed in, it will be based on the
#  |          corresponding values of the pd.Series.
#  |        ends (Union[LinearExprT, pd.Series]): The ends of each interval in the
#  |          set. If a `pd.Series` is passed in, it will be based on the
#  |          corresponding values of the pd.Series.
#  |
#  |      Returns:
#  |        pd.Series: The interval variable set indexed by its corresponding
#  |        dimensions.
#  |
#  |      Raises:
#  |        TypeError: if the `index` is invalid (e.g. a `DataFrame`).
#  |        ValueError: if the `name` is not a valid identifier or already exists.
#  |        ValueError: if the all the indexes do not match.
#  |
#  |  new_optional_fixed_size_interval_var(self, start: Union[ForwardRef('LinearExpr'), ForwardRef('IntVar'), numbers.Integral, int], size: Union[numbers.Integral, int], is_present: Union[ForwardRef('IntVar'), ForwardRef('_NotBooleanVariable'), numbers.Integral, int, bool], name: str) -> ortools.sat.python.cp_model.IntervalVar
#  |      Creates an interval variable from start, and a fixed size.
#  |
#  |      An interval variable is a constraint, that is itself used in other
#  |      constraints like NoOverlap.
#  |
#  |      Args:
#  |        start: The start of the interval. It must be of the form a * var + b.
#  |        size: The size of the interval. It must be an integer value.
#  |        is_present: A literal that indicates if the interval is active or not. A
#  |          inactive interval is simply ignored by all constraints.
#  |        name: The name of the interval variable.
#  |
#  |      Returns:
#  |        An `IntervalVar` object.
#  |
#  |  new_optional_fixed_size_interval_var_series(self, name: str, index: pandas.core.indexes.base.Index, starts: Union[ForwardRef('LinearExpr'), ForwardRef('IntVar'), numbers.Integral, int, pandas.core.series.Series], sizes: Union[numbers.Integral, int, pandas.core.series.Series], are_present: Union[ForwardRef('IntVar'), ForwardRef('_NotBooleanVariable'), numbers.Integral, int, bool, pandas.core.series.Series]) -> pandas.core.series.Series
#  |      Creates a series of interval variables with the given name.
#  |
#  |      Args:
#  |        name (str): Required. The name of the variable set.
#  |        index (pd.Index): Required. The index to use for the variable set.
#  |        starts (Union[LinearExprT, pd.Series]): The start of each interval in the
#  |          set. If a `pd.Series` is passed in, it will be based on the
#  |          corresponding values of the pd.Series.
#  |        sizes (Union[IntegralT, pd.Series]): The fixed size of each interval in
#  |          the set. If a `pd.Series` is passed in, it will be based on the
#  |          corresponding values of the pd.Series.
#  |        are_present (Union[LiteralT, pd.Series]): The performed literal of each
#  |          interval in the set. If a `pd.Series` is passed in, it will be based on
#  |          the corresponding values of the pd.Series.
#  |
#  |      Returns:
#  |        pd.Series: The interval variable set indexed by its corresponding
#  |        dimensions.
#  |
#  |      Raises:
#  |        TypeError: if the `index` is invalid (e.g. a `DataFrame`).
#  |        ValueError: if the `name` is not a valid identifier or already exists.
#  |        ValueError: if the all the indexes do not match.
#  |
#  |  new_optional_interval_var(self, start: Union[ForwardRef('LinearExpr'), ForwardRef('IntVar'), numbers.Integral, int], size: Union[ForwardRef('LinearExpr'), ForwardRef('IntVar'), numbers.Integral, int], end: Union[ForwardRef('LinearExpr'), ForwardRef('IntVar'), numbers.Integral, int], is_present: Union[ForwardRef('IntVar'), ForwardRef('_NotBooleanVariable'), numbers.Integral, int, bool], name: str) -> ortools.sat.python.cp_model.IntervalVar
#  |      Creates an optional interval var from start, size, end, and is_present.
#  |
#  |      An optional interval variable is a constraint, that is itself used in other
#  |      constraints like NoOverlap. This constraint is protected by a presence
#  |      literal that indicates if it is active or not.
#  |
#  |      Internally, it ensures that `is_present` implies `start + size ==
#  |      end`.
#  |
#  |      Args:
#  |        start: The start of the interval. It must be of the form a * var + b.
#  |        size: The size of the interval. It must be of the form a * var + b.
#  |        end: The end of the interval. It must be of the form a * var + b.
#  |        is_present: A literal that indicates if the interval is active or not. A
#  |          inactive interval is simply ignored by all constraints.
#  |        name: The name of the interval variable.
#  |
#  |      Returns:
#  |        An `IntervalVar` object.
#  |
#  |  new_optional_interval_var_series(self, name: str, index: pandas.core.indexes.base.Index, starts: Union[ForwardRef('LinearExpr'), ForwardRef('IntVar'), numbers.Integral, int, pandas.core.series.Series], sizes: Union[ForwardRef('LinearExpr'), ForwardRef('IntVar'), numbers.Integral, int, pandas.core.series.Series], ends: Union[ForwardRef('LinearExpr'), ForwardRef('IntVar'), numbers.Integral, int, pandas.core.series.Series], are_present: Union[ForwardRef('IntVar'), ForwardRef('_NotBooleanVariable'), numbers.Integral, int, bool, pandas.core.series.Series]) -> pandas.core.series.Series
#  |      Creates a series of interval variables with the given name.
#  |
#  |      Args:
#  |        name (str): Required. The name of the variable set.
#  |        index (pd.Index): Required. The index to use for the variable set.
#  |        starts (Union[LinearExprT, pd.Series]): The start of each interval in the
#  |          set. If a `pd.Series` is passed in, it will be based on the
#  |          corresponding values of the pd.Series.
#  |        sizes (Union[LinearExprT, pd.Series]): The size of each interval in the
#  |          set. If a `pd.Series` is passed in, it will be based on the
#  |          corresponding values of the pd.Series.
#  |        ends (Union[LinearExprT, pd.Series]): The ends of each interval in the
#  |          set. If a `pd.Series` is passed in, it will be based on the
#  |          corresponding values of the pd.Series.
#  |        are_present (Union[LiteralT, pd.Series]): The performed literal of each
#  |          interval in the set. If a `pd.Series` is passed in, it will be based on
#  |          the corresponding values of the pd.Series.
#  |
#  |      Returns:
#  |        pd.Series: The interval variable set indexed by its corresponding
#  |        dimensions.
#  |
#  |      Raises:
#  |        TypeError: if the `index` is invalid (e.g. a `DataFrame`).
#  |        ValueError: if the `name` is not a valid identifier or already exists.
#  |        ValueError: if the all the indexes do not match.
#  |
#  |  parse_linear_expression(self, linear_expr: Union[ForwardRef('LinearExpr'), ForwardRef('IntVar'), numbers.Integral, int], negate: bool = False) -> ortools.sat.cp_model_pb2.LinearExpressionProto
#  |      Returns a LinearExpressionProto built from a LinearExpr instance.
#  |
#  |  rebuild_constant_map(self)
#  |      Internal method used during model cloning.
#  |
#  |  validate(self) -> str
#  |      Returns a string indicating that the model is invalid.
#  |
#  |  var_index_to_var_proto(self, var_index: int) -> ortools.sat.cp_model_pb2.IntegerVariableProto
#  |
#  |  ----------------------------------------------------------------------
#  |  Readonly properties defined here:
#  |
#  |  proto
#  |      Returns the underlying CpModelProto.
#  |
#  |  ----------------------------------------------------------------------
#  |  Data descriptors defined here:
#  |
#  |  __dict__
#  |      dictionary for instance variables (if defined)
#  |
#  |  __weakref__
#  |      list of weak references to the object (if defined)
#  |
#  |  name
#  |      Returns the name of the model.

# %%
x = {}
x[2,3]  = 5

# %%
x.keys()
# Out:
# dict_keys([(2, 3)])
